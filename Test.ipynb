# %%
import pandas as pd 
import numpy as np 
df=pd.read_csv('cleaned_dataset_1.csv')
df
# Out:
#         Unnamed: 0.1  Unnamed: 0            Bearer Id  Start ms  End ms  \
# 0                  0           0  9223372036854775807       770     662
# 1                  1           1  9223372036854775807       235     606
# 2                  2           2  9223372036854775807         1     652
# 3                  3           3  9223372036854775807       486     171
# 4                  4           4  9223372036854775807       565     954
# ...              ...         ...                  ...       ...     ...
# 149996        149996      149996  7277825670196679680       451     214
# 149997        149997      149997  7349883264234609664       483     187
# 149998        149998      149998  9223372036854775807       283     810
# 149999        149999      149999  9223372036854775807       696     327
# 150000        150000      150000  9223372036854775807       499     498
#
#         Dur. (ms)             IMSI  MSISDN/Number            IMEI  \
# ...

# %%
data=df['Start']
data
data_split = [entry.split() for entry in data]

# Create a DataFrame
df = pd.DataFrame(data_split, columns=["Date", "Time"])

# Display the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Start'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data=df['Start']
#       2 data
# ...

# %%
df['Last Location Name'].unique()
# Out:
# '9.16456699548519E+015L77566AD42335AT21824AD88865AT89132C9.16456701058919E+015CELL_208_20_520025_1T42084AL20434CT29911AT21335CD76026BT88606BT21481BT72184AD88942CD93750CT29714BD14033BT84551AT76876BD11497BD83926CT72910CL77568BD14000AL16660BT77577BT30020CD78087AD11221BD34244AT86868AD79735AT00750CL72490AD93202AD72939C9.....16456699548518E+015L79699CD16660CD93720BD78467BL42154AT96034BD96127CL42065BD11480A9......_208_20_23022
# ...

# %%
df.select_dtypes(include='object')
# Out:
#            Last Location Name Handset Manufacturer  \
# 0       9.16456699548519E+015              Samsung
# 1                     L77566A              Samsung
# 2                     D42335A              Samsung
# 3                     T21824A            undefined
# 4                     D88865A              Samsung
# ...                       ...                  ...
# 149996                D20434A                Apple
# 149997                D10223C                Apple
# 149998                T51102A                Apple
# 149999                L88342B               Huawei
# 150000                D41377B                Apple
#
#                        Handset Type Manufacturer   StartDate StartTime  \
# 0        Samsung Galaxy A5 Sm-A520F      Samsung  2019-04-04  14:35:00
# 1       Samsung Galaxy J5 (Sm-J530)      Samsung  2019-04-09  08:15:00
# 2          Samsung Galaxy A8 (2018)      Samsung  2019-04-09  11:58:00
# ...
